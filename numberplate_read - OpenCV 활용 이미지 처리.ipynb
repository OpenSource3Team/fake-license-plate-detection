# %% [markdown]
# # 자동차 번호판 인식 with OpenCV

# %%
! pip install ultralytics opencv-python pytesseract
! apt-get install -y tesseract-ocr

# Python용 pytesseract 라이브러리 설치
! pip install pytesseract
! pip install opencv-python-headless

! apt-get install -y tesseract-ocr-kor

# !pip install opencv-python
# !pip install matplotlib

# yolo v5 clone
! git clone https://github.com/allowedr/HBOS3.git
! pip install -r HBOS3/requirements.txt
# Out:
# Requirement already satisfied: ultralytics in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (8.3.2)
# Requirement already satisfied: opencv-python in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (4.10.0.84)
# Requirement already satisfied: pytesseract in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (0.3.13)
# Requirement already satisfied: numpy<2.0.0,>=1.23.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from ultralytics) (1.26.4)
# Requirement already satisfied: matplotlib>=3.3.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from ultralytics) (3.9.2)
# Requirement already satisfied: pillow>=7.1.2 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from ultralytics) (10.4.0)
# Requirement already satisfied: pyyaml>=5.3.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from ultralytics) (6.0.2)
# Requirement already satisfied: requests>=2.23.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from ultralytics) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from ultralytics) (1.14.1)
# Requirement already satisfied: torch>=1.8.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from ultralytics) (2.4.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from ultralytics) (0.19.1)
# Requirement already satisfied: tqdm>=4.64.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from ultralytics) (4.66.5)
# Requirement already satisfied: psutil in c:\users\rkdal\appdata\roaming\python\python312\site-packages (from ultralytics) (6.0.0)
# Requirement already satisfied: py-cpuinfo in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from ultralytics) (9.0.0)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from ultralytics) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from ultralytics) (0.13.2)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from ultralytics) (2.0.8)
# Requirement already satisfied: packaging>=21.3 in c:\users\rkdal\appdata\roaming\python\python312\site-packages (from pytesseract) (24.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from matplotlib>=3.3.0->ultralytics) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rkdal\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3.0->ultralytics) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from pandas>=1.1.4->ultralytics) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from requests>=2.23.0->ultralytics) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from requests>=2.23.0->ultralytics) (2024.8.30)
# Requirement already satisfied: filelock in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from torch>=1.8.0->ultralytics) (4.12.2)
# Requirement already satisfied: sympy in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from torch>=1.8.0->ultralytics) (1.13.3)
# Requirement already satisfied: networkx in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.3)
# Requirement already satisfied: jinja2 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from torch>=1.8.0->ultralytics) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from torch>=1.8.0->ultralytics) (2024.9.0)
# Requirement already satisfied: setuptools in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from torch>=1.8.0->ultralytics) (75.1.0)
# Requirement already satisfied: colorama in c:\users\rkdal\appdata\roaming\python\python312\site-packages (from tqdm>=4.64.0->ultralytics) (0.4.6)
# Requirement already satisfied: six>=1.5 in c:\users\rkdal\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from jinja2->torch>=1.8.0->ultralytics) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from sympy->torch>=1.8.0->ultralytics) (1.3.0)
# 'apt-get'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# Requirement already satisfied: pytesseract in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (0.3.13)
# Requirement already satisfied: packaging>=21.3 in c:\users\rkdal\appdata\roaming\python\python312\site-packages (from pytesseract) (24.1)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from pytesseract) (10.4.0)
# Requirement already satisfied: opencv-python-headless in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from opencv-python-headless) (1.26.4)
# 'apt-get'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.
# Requirement already satisfied: opencv-python in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: matplotlib in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (3.9.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from matplotlib) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\rkdal\appdata\roaming\python\python312\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from matplotlib) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rkdal\appdata\roaming\python\python312\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\rkdal\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Cloning into 'HBOS3'...
# Updating files:  45% (2962/6537)
# Updating files:  46% (3008/6537)
# Updating files:  47% (3073/6537)
# Updating files:  48% (3138/6537)
# Updating files:  49% (3204/6537)
# Updating files:  50% (3269/6537)
# Updating files:  51% (3334/6537)
# Updating files:  52% (3400/6537)
# Updating files:  53% (3465/6537)
# Updating files:  54% (3530/6537)
# Updating files:  55% (3596/6537)
# Updating files:  56% (3661/6537)
# Updating files:  57% (3727/6537)
# Updating files:  58% (3792/6537)
# Updating files:  59% (3857/6537)
# Updating files:  60% (3923/6537)
# Updating files:  61% (3988/6537)
# Updating files:  62% (4053/6537)
# Updating files:  63% (4119/6537)
# Updating files:  64% (4184/6537)
# Updating files:  65% (4250/6537)
# Updating files:  66% (4315/6537)
# Updating files:  67% (4380/6537)
# Updating files:  68% (4446/6537)
# Updating files:  69% (4511/6537)
# Updating files:  70% (4576/6537)
# Updating files:  71% (4642/6537)
# Updating files:  72% (4707/6537)
# Updating files:  73% (4773/6537)
# Updating files:  74% (4838/6537)
# Updating files:  75% (4903/6537)
# Updating files:  76% (4969/6537)
# Updating files:  77% (5034/6537)
# Updating files:  78% (5099/6537)
# Updating files:  79% (5165/6537)
# Updating files:  80% (5230/6537)
# Updating files:  81% (5295/6537)
# Updating files:  82% (5361/6537)
# Updating files:  83% (5426/6537)
# Updating files:  84% (5492/6537)
# Updating files:  85% (5557/6537)
# Updating files:  86% (5622/6537)
# Updating files:  87% (5688/6537)
# Updating files:  88% (5753/6537)
# Updating files:  89% (5818/6537)
# Updating files:  90% (5884/6537)
# Updating files:  91% (5949/6537)
# Updating files:  92% (6015/6537)
# Updating files:  93% (6080/6537)
# Updating files:  94% (6145/6537)
# Updating files:  95% (6211/6537)
# Updating files:  96% (6276/6537)
# Updating files:  97% (6341/6537)
# Updating files:  97% (6346/6537)
# Updating files:  98% (6407/6537)
# Updating files:  99% (6472/6537)
# Updating files: 100% (6537/6537)
# Updating files: 100% (6537/6537), done.
# Requirement already satisfied: gitpython>=3.1.30 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from -r HBOS3/requirements.txt (line 5)) (3.1.43)
# Requirement already satisfied: matplotlib>=3.3 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from -r HBOS3/requirements.txt (line 6)) (3.9.2)
# Requirement already satisfied: numpy>=1.23.5 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from -r HBOS3/requirements.txt (line 7)) (1.26.4)
# Requirement already satisfied: opencv-python>=4.1.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from -r HBOS3/requirements.txt (line 8)) (4.10.0.84)
# Requirement already satisfied: pillow>=10.3.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from -r HBOS3/requirements.txt (line 9)) (10.4.0)
# Requirement already satisfied: psutil in c:\users\rkdal\appdata\roaming\python\python312\site-packages (from -r HBOS3/requirements.txt (line 10)) (6.0.0)
# Requirement already satisfied: PyYAML>=5.3.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from -r HBOS3/requirements.txt (line 11)) (6.0.2)
# Requirement already satisfied: requests>=2.32.2 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from -r HBOS3/requirements.txt (line 12)) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from -r HBOS3/requirements.txt (line 13)) (1.14.1)
# Requirement already satisfied: thop>=0.1.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from -r HBOS3/requirements.txt (line 14)) (0.1.1.post2209072238)
# Requirement already satisfied: torch>=1.8.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from -r HBOS3/requirements.txt (line 15)) (2.4.1)
# Requirement already satisfied: torchvision>=0.9.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from -r HBOS3/requirements.txt (line 16)) (0.19.1)
# Requirement already satisfied: tqdm>=4.66.3 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from -r HBOS3/requirements.txt (line 17)) (4.66.5)
# Requirement already satisfied: ultralytics>=8.2.34 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from -r HBOS3/requirements.txt (line 18)) (8.3.2)
# Requirement already satisfied: pandas>=1.1.4 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from -r HBOS3/requirements.txt (line 27)) (2.2.3)
# Requirement already satisfied: seaborn>=0.11.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from -r HBOS3/requirements.txt (line 28)) (0.13.2)
# Requirement already satisfied: setuptools>=70.0.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from -r HBOS3/requirements.txt (line 42)) (75.1.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from gitpython>=3.1.30->-r HBOS3/requirements.txt (line 5)) (4.0.11)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from matplotlib>=3.3->-r HBOS3/requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from matplotlib>=3.3->-r HBOS3/requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from matplotlib>=3.3->-r HBOS3/requirements.txt (line 6)) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from matplotlib>=3.3->-r HBOS3/requirements.txt (line 6)) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\rkdal\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3->-r HBOS3/requirements.txt (line 6)) (24.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from matplotlib>=3.3->-r HBOS3/requirements.txt (line 6)) (3.1.4)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\rkdal\appdata\roaming\python\python312\site-packages (from matplotlib>=3.3->-r HBOS3/requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from requests>=2.32.2->-r HBOS3/requirements.txt (line 12)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from requests>=2.32.2->-r HBOS3/requirements.txt (line 12)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from requests>=2.32.2->-r HBOS3/requirements.txt (line 12)) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from requests>=2.32.2->-r HBOS3/requirements.txt (line 12)) (2024.8.30)
# Requirement already satisfied: filelock in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from torch>=1.8.0->-r HBOS3/requirements.txt (line 15)) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from torch>=1.8.0->-r HBOS3/requirements.txt (line 15)) (4.12.2)
# Requirement already satisfied: sympy in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from torch>=1.8.0->-r HBOS3/requirements.txt (line 15)) (1.13.3)
# Requirement already satisfied: networkx in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from torch>=1.8.0->-r HBOS3/requirements.txt (line 15)) (3.3)
# Requirement already satisfied: jinja2 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from torch>=1.8.0->-r HBOS3/requirements.txt (line 15)) (3.1.4)
# Requirement already satisfied: fsspec in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from torch>=1.8.0->-r HBOS3/requirements.txt (line 15)) (2024.9.0)
# Requirement already satisfied: colorama in c:\users\rkdal\appdata\roaming\python\python312\site-packages (from tqdm>=4.66.3->-r HBOS3/requirements.txt (line 17)) (0.4.6)
# Requirement already satisfied: py-cpuinfo in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from ultralytics>=8.2.34->-r HBOS3/requirements.txt (line 18)) (9.0.0)
# Requirement already satisfied: ultralytics-thop>=2.0.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from ultralytics>=8.2.34->-r HBOS3/requirements.txt (line 18)) (2.0.8)
# Requirement already satisfied: pytz>=2020.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from pandas>=1.1.4->-r HBOS3/requirements.txt (line 27)) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from pandas>=1.1.4->-r HBOS3/requirements.txt (line 27)) (2024.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from gitdb<5,>=4.0.1->gitpython>=3.1.30->-r HBOS3/requirements.txt (line 5)) (5.0.1)
# Requirement already satisfied: six>=1.5 in c:\users\rkdal\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.7->matplotlib>=3.3->-r HBOS3/requirements.txt (line 6)) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from jinja2->torch>=1.8.0->-r HBOS3/requirements.txt (line 15)) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in c:\users\rkdal\.conda\envs\newenv\lib\site-packages (from sympy->torch>=1.8.0->-r HBOS3/requirements.txt (line 15)) (1.3.0)

# %%
"""파일 목록 전체 검사"""

# !python HBOS3/detect1.py --weights HBOS3/best.pt --source HBOS3/pic/pic/*.jpg --save-crop
# Out:
# 인식이 되지 않았습니다 재진입하십시오
# detect1: weights=['HBOS3/best.pt'], source=HBOS3/pic/pic/*.jpg, data=HBOS3\data\coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=True, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=HBOS3\runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5  ea52607 Python-3.12.5 torch-2.4.1+cpu CPU
#
# Fusing layers...
# Model summary: 157 layers, 1760518 parameters, 0 gradients, 4.1 GFLOPs
# image 1/98 C:\Users\rkdal\Downloads\HBOS3\pic\pic\013733.jpg: 288x640 1 license_plate, 87.7ms
# image 2/98 C:\Users\rkdal\Downloads\HBOS3\pic\pic\010598.jpg: 352x640 1 license_plate, 130.4ms
# image 3/98 C:\Users\rkdal\Downloads\HBOS3\pic\pic\010608.jpg: 480x640 1 license_plate, 67.1ms
# image 4/98 C:\Users\rkdal\Downloads\HBOS3\pic\pic\018109.jpg: 288x640 1 license_plate, 36.6ms
# image 5/98 C:\Users\rkdal\Downloads\HBOS3\pic\pic\010665.jpg: 256x640 1 license_plate, 61.1ms
# image 6/98 C:\Users\rkdal\Downloads\HBOS3\pic\pic\015511.jpg: 288x640 1 license_plate, 57.8ms
# image 7/98 C:\Users\rkdal\Downloads\HBOS3\pic\pic\011275.jpg: 288x640 1 license_plate, 130.0ms
# image 8/98 C:\Users\rkdal\Downloads\HBOS3\pic\pic\017076.jpg: 288x640 1 license_plate, 95.8ms
# image 9/98 C:\Users\rkdal\Downloads\HBOS3\pic\pic
7ms NMS per image at shape (1, 3, 640, 640)
# Results saved to HBOS3\runs\detect\result
# 인식이 되지 않았습니다 재진입하십시오
# 01고8105
#
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 01도8490
#
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
#
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
#
# 01루0099
#
# 01마3235
#
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 01모3154
#
# 인식이 되지 않았습니다 재진입하십시오
# 01무0609
#
# 인식이 되지 않았습니다 재진입하십시오
# 01보9398
#
#
#
#
# 인식이 되지 않았습니다 재진입하십시오
# 01수7052
#
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 18소7797
#
# 인식이 되지 않았습니다 재진입하십시오
# 18어0103
#
# 인식이 되지 않았습니다 재진입하십시오
# 18어6183
#
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 18오0746
#
# 18오0905
#
# 18오2785
#
# 인식이 되지 않았습니다 재진입하십시오
#
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 18저4130
#
#
# 인식이 되지 않았습니다 재진입하십시오
# 18조4654
#
# 18주1609
#
# 18주6471
#
# 18주6471
#
# 인식이 되지 않았습니다 재진입하십시오
# 18아3306
#
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 18호6127
#
# 18호6127
#
#
#
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 19거1552
#
# 19거8630
#
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 212구6506
#
# 인식이 되지 않았습니다 재진입하십시오
# 19노0141
#
#
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
#
# 19도2055
#
# 19도3858
#
#
# 인식이 되지 않았습니다 재진입하십시오
# 19우3492
#
#
# 19두6906
#
#
# 인식이 되지 않았습니다 재진입하십시오
#
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 인식이 되지 않았습니다 재진입하십시오
# 19러1998
#
#
# 19로8121

# %% [markdown]
# ## 1. 라이브러리 호출

# %%
import os
import cv2
os.environ['KMP_DUPLICATE_LIB_OK']='True'   #기기에 설치된 소프트웨어적인 문제로 인한 임시조치
import numpy as np
import torch
import pandas as pd
import matplotlib.pyplot as plt
import pytesseract
plt.style.use('dark_background')
pytesseract.pytesseract.tesseract_cmd = 'C:/Program Files/Tesseract-OCR/tesseract.exe'

# %% [markdown]
# ## 2. Read Input Image

# %%
"""
- 특정 폴더 내에 있는 "가장 최근에 생성된" 파일을 리턴 
"""
folder_path = 'HBOS3/runs/detect/result/crops/license_plate/'

# each_file_path_and_gen_time: 각 file의 경로와, 생성 시간을 저장함
each_file_path_and_gen_time = []
for each_file_name in os.listdir(folder_path):
    # getctime: 입력받은 경로에 대한 생성 시간을 리턴
    each_file_path = folder_path + each_file_name
    each_file_gen_time = os.path.getctime(each_file_path)
    each_file_path_and_gen_time.append(
        (each_file_path, each_file_gen_time)
    )

# 가장 생성시각이 큰(가장 최근인) 파일을 리턴 
most_recent_file = max(each_file_path_and_gen_time, key=lambda x: x[1])[0]  #가장 최근에 찍힌 번호판 이미지
print(most_recent_file)
img_ori = cv2.imread(most_recent_file)      #most_recent_file




height, width, channel = img_ori.shape
channel = 1

# Morphology Operation
StructuringElement = cv2.getStructuringElement(cv2.MORPH_RECT, (3, 3))
topHat = cv2.morphologyEx(img_ori, cv2.MORPH_TOPHAT, StructuringElement)
blackHat = cv2.morphologyEx(img_ori, cv2.MORPH_BLACKHAT, StructuringElement)
img_topHat = cv2.add(img_ori, topHat)
img_ori = cv2.subtract(img_topHat, blackHat)
gray = cv2.cvtColor(img_ori, cv2.COLOR_BGR2GRAY)
# Gaussian Blurring
blur = cv2.GaussianBlur(gray, (5, 5), 2)

# Adaptive Thresholding
img_blurred = cv2.GaussianBlur(gray, ksize=(5, 5), sigmaX=0)

img_blur_thresh = cv2.adaptiveThreshold(
img_blurred,
maxValue=255.0,
adaptiveMethod=cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
thresholdType=cv2.THRESH_BINARY_INV,
blockSize=19,
C=9
)
plt.figure(figsize=(12, 10))
plt.imshow(img_ori,cmap='gray')
print(height, width, channel)
# Out:
# HBOS3/runs/detect/result/crops/license_plate/Enter--2024-12-02_14-51-392.jpg
# 102 313 1

# %% [markdown]
# ## 3. Convert Image to Grayscale
#
# * BGR -> GRAY 변환법
# 1. BGR2GRAY
# ```python
# cv2.cvtColor(이미지, cv2.COLOR_BGR2GRAY)
# ```
# 2. hsv
# ```python
# hsv = cv2.cvtColor(img_ori, cv2.COLOR_BGR2HSV)
# gray = hsv[:, :, 2]
# ```

# %%
def img_to_gray(image, image_show=True):
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    if image_show:
        plt.figure(figsize=(7,5))
        plt.imshow(gray, cmap='gray')
        plt.title('흑백화')
    return gray

# %% [markdown]
# ## 4. Adaptive Thresholding
#
# * GaussianBlur
# : 노이즈를 줄이기 위해
#
# * adaptiveThreshold
# : threshold 보다 낮은 값 = 0, 높은 값 : 255
# : 이미지 구분을 쉽게 만들어줌

# %%
img_blurred = cv2.GaussianBlur(gray, ksize=(5, 5), sigmaX=0)

img_blur_thresh = cv2.adaptiveThreshold(
    img_blurred,
    maxValue=255.0,
    adaptiveMethod=cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
    thresholdType=cv2.THRESH_BINARY_INV,
    blockSize=19,
    C=11
)
plt.figure(figsize=(8,5))
plt.imshow(img_blur_thresh, cmap='gray')

# %% [markdown]
# ## 5. Find Contours
#
# 이미지에서 윤곽선 찾기
#
# ※ 변경사항
# : findContours() 함수의 리턴 값이 3개라고 많은 자료들이 말함 -> 2개로 바뀐듯함

# %%
contours, _ = cv2.findContours(
    img_blur_thresh,
    mode=cv2.RETR_LIST,
    method=cv2.CHAIN_APPROX_SIMPLE
)

temp_result = np.zeros((height, width, channel), dtype=np.uint8)

cv2.drawContours(temp_result, contours=contours, contourIdx=-1, color=(255,255,255))

plt.figure(figsize=(12, 10))
plt.imshow(temp_result)

# %% [markdown]
# ## 6. Prepare Data

# %%
temp_result = np.zeros((height, width, channel), dtype=np.uint8)

contours_dict = []

for contour in contours:
    x, y, w, h = cv2.boundingRect(contour)
    cv2.rectangle(temp_result, pt1=(x,y), pt2=(x+w, y+h), color=(255,255,255), thickness=2)
    
    contours_dict.append({
        'contour': contour,
        'x': x,
        'y': y,
        'w': w,
        'h': h,
        'cx': x + (w / 2),
        'cy': y + (h / 2)
    })
    
plt.figure(figsize=(12,10))
plt.imshow(temp_result, cmap='gray')

# %% [markdown]
# ## 7. Select Candidates by Char Size

# %%
MIN_AREA = 80
MIN_WIDTH, MIN_HEIGHT=2, 8
MIN_RATIO, MAX_RATIO = 0.2, 1.0

possible_contours = []

cnt = 0
for d in contours_dict:
    area = d['w'] * d['h']
    ratio = d['w'] / d['h']
    
    if area > MIN_AREA \
    and d['w'] > MIN_WIDTH and d['h'] > MIN_HEIGHT \
    and MIN_RATIO < ratio < MAX_RATIO:
        d['idx'] = cnt
        cnt += 1
        possible_contours.append(d)

temp_result = np.zeros((height, width, channel), dtype = np.uint8)

for d in possible_contours:
    cv2.rectangle(temp_result, pt1=(d['x'], d['y']), pt2=(d['x']+d['w'], d['y']+d['h']), color=(255, 255, 255), thickness=2)
    
plt.figure(figsize=(12, 10))
plt.imshow(temp_result, cmap='gray')

# %% [markdown]
# ## 8. Select Candidates by Arrangement of Contours

# %%
MAX_DIAG_MULTIPLYER = 5
MAX_ANGLE_DIFF = 12.0
MAX_AREA_DIFF = 0.5
MAX_WIDTH_DIFF = 0.8
MAX_HEIGHT_DIFF = 0.2
MIN_N_MATCHED = 3

def find_chars(contour_list):
    matched_result_idx = []
    
    for d1 in contour_list:
        matched_contours_idx = []
        for d2 in contour_list:
            if d1['idx'] == d2['idx']:
                continue
                
            dx = abs(d1['cx'] - d2['cx'])
            dy = abs(d1['cy'] - d2['cy'])
            
            diagonal_length1 = np.sqrt(d1['w'] ** 2 + d1['h'] ** 2)
            
            distance = np.linalg.norm(np.array([d1['cx'], d1['cy']]) - np.array([d2['cx'], d2['cy']]))
            if dx == 0:
                angle_diff = 90
            else:
                angle_diff = np.degrees(np.arctan(dy / dx))
            area_diff = abs(d1['w'] * d1['h'] - d2['w'] * d2['h']) / (d1['w'] * d1['h'])
            width_diff = abs(d1['w'] - d2['w']) / d1['w']
            height_diff = abs(d1['h'] - d2['h']) / d1['h']
            
            if distance < diagonal_length1 * MAX_DIAG_MULTIPLYER \
            and angle_diff < MAX_ANGLE_DIFF and area_diff < MAX_AREA_DIFF \
            and width_diff < MAX_WIDTH_DIFF and height_diff < MAX_HEIGHT_DIFF:
                matched_contours_idx.append(d2['idx'])
                
        matched_contours_idx.append(d1['idx'])
        
        if len(matched_contours_idx) < MIN_N_MATCHED:
            continue
            
        matched_result_idx.append(matched_contours_idx)
        
        unmatched_contour_idx = []
        for d4 in contour_list:
            if d4['idx'] not in matched_contours_idx:
                unmatched_contour_idx.append(d4['idx'])
        
        unmatched_contour = np.take(possible_contours, unmatched_contour_idx)
        
        recursive_contour_list = find_chars(unmatched_contour)
        
        for idx in recursive_contour_list:
            matched_result_idx.append(idx)
            
        break
        
    return matched_result_idx

result_idx = find_chars(possible_contours)

matched_result = []
for idx_list in result_idx:
    matched_result.append(np.take(possible_contours, idx_list))
    
temp_result = np.zeros((height, width, channel), dtype=np.uint8)

for r in matched_result:
    for d in r:
        cv2.rectangle(temp_result, pt1=(d['x'], d['y']), pt2=(d['x']+d['w'], d['y']+d['h']), color=(255,255,255), thickness=2)

plt.figure(figsize=(12, 10))
plt.imshow(temp_result, cmap='gray')

# %% [markdown]
# ## 9. Rotate Plate Images

# %%
PLATE_WIDTH_PADDING = 1.3 # 1.3
PLATE_HEIGHT_PADDING = 1.5 # 1.5
MIN_PLATE_RATIO = 3
MAX_PLATE_RATIO = 10

plate_imgs = []
plate_infos = []

for i, matched_chars in enumerate(matched_result):
    sorted_chars = sorted(matched_chars, key=lambda x: x['cx'])

    plate_cx = (sorted_chars[0]['cx'] + sorted_chars[-1]['cx']) / 2
    plate_cy = (sorted_chars[0]['cy'] + sorted_chars[-1]['cy']) / 2
    
    plate_width = (sorted_chars[-1]['x'] + sorted_chars[-1]['w'] - sorted_chars[0]['x']) * PLATE_WIDTH_PADDING
    
    sum_height = 0
    for d in sorted_chars:
        sum_height += d['h']

    plate_height = int(sum_height / len(sorted_chars) * PLATE_HEIGHT_PADDING)
    
    triangle_height = sorted_chars[-1]['cy'] - sorted_chars[0]['cy']
    triangle_hypotenus = np.linalg.norm(
        np.array([sorted_chars[0]['cx'], sorted_chars[0]['cy']]) - 
        np.array([sorted_chars[-1]['cx'], sorted_chars[-1]['cy']])
    )
    
    angle = np.degrees(np.arcsin(triangle_height / triangle_hypotenus))
    
    rotation_matrix = cv2.getRotationMatrix2D(center=(plate_cx, plate_cy), angle=angle, scale=1.0)
    
    img_rotated = cv2.warpAffine(img_blur_thresh, M=rotation_matrix, dsize=(width, height))
    
    img_cropped = cv2.getRectSubPix(
        img_rotated, 
        patchSize=(int(plate_width), int(plate_height)), 
        center=(int(plate_cx), int(plate_cy))
    )
    
    if img_cropped.shape[1] / img_cropped.shape[0] < MIN_PLATE_RATIO or img_cropped.shape[1] / img_cropped.shape[0] < MIN_PLATE_RATIO > MAX_PLATE_RATIO:
        continue
    
    plate_imgs.append(img_cropped)
    plate_infos.append({
        'x': int(plate_cx - plate_width / 2),
        'y': int(plate_cy - plate_height / 2),
        'w': int(plate_width),
        'h': int(plate_height)
    })
    
    plt.subplot(len(matched_result), 1, i+1)
    plt.imshow(img_cropped, cmap='gray')

# %% [markdown]
# ## 10. Another Thresholding
#
# ## 11. Find Chars   확인 필요

# %%
longest_idx, longest_text = -1, 0
plate_chars = []

for i, plate_img in enumerate(plate_imgs):
    plate_img = cv2.resize(plate_img, dsize=(0, 0), fx=1.6, fy=1.6)
    _, plate_img = cv2.threshold(plate_img, thresh=0.0, maxval=255.0, type=cv2.THRESH_BINARY | cv2.THRESH_OTSU)
    
    # find contours again (same as above)
    contours, _ = cv2.findContours(plate_img, mode=cv2.RETR_LIST, method=cv2.CHAIN_APPROX_SIMPLE)
    
    plate_min_x, plate_min_y = plate_img.shape[1], plate_img.shape[0]
    plate_max_x, plate_max_y = 0, 0

    for contour in contours:
        x, y, w, h = cv2.boundingRect(contour)
        
        area = w * h
        ratio = w / h

        if area > MIN_AREA \
        and w > MIN_WIDTH and h > MIN_HEIGHT \
        and MIN_RATIO < ratio < MAX_RATIO:
            if x < plate_min_x:
                plate_min_x = x
            if y < plate_min_y:
                plate_min_y = y
            if x + w > plate_max_x:
                plate_max_x = x + w
            if y + h > plate_max_y:
                plate_max_y = y + h
                
    img_result = plate_img[plate_min_y:plate_max_y, plate_min_x:plate_max_x]
    
    img_result = cv2.GaussianBlur(img_result, ksize=(3, 3), sigmaX=0)
    _, img_result = cv2.threshold(img_result, thresh=0.0, maxval=255.0, type=cv2.THRESH_BINARY | cv2.THRESH_OTSU)
    img_result = cv2.copyMakeBorder(img_result, top=10, bottom=10, left=10, right=10, borderType=cv2.BORDER_CONSTANT, value=(0,0,0))
    
    chars = pytesseract.image_to_string(img_result, lang='kornum+kor', config='--psm 6 preserve_interword_spaces')
    #chars = pytesseract.image_to_string(img_result, lang='kornum+kor', config='--psm 7 --oem 3')
    
    result_chars = ''
    has_digit = False
    for c in chars:
        if ord('가') <= ord(c) <= ord('힣') or c.isdigit():
            if c.isdigit():
                has_digit = True
            result_chars += c
    
    print(result_chars)
    plate_chars.append(result_chars)

    if has_digit and len(result_chars) > longest_text:
        longest_idx = i

    plt.subplot(len(plate_imgs), 1, i+1)
    plt.imshow(img_result, cmap='gray')
# Out:
# 19노0141

# %% [markdown]
# ## 12. Result

# %%
try :
    info = plate_infos[longest_idx]
    chars = plate_chars[longest_idx]
    if ord('가') <= ord(chars[2]) <= ord('힣') and len(chars) == 7:
        print(chars)
        #excel()
    elif ord('가') <= ord(chars[3]) <= ord('힣') and len(chars) == 8:
        print(chars)
        #excel()
    else :
        print('인식이 되지 않았습니다 재진입하십시오')

    img_out = img_ori.copy()

    cv2.rectangle(img_out, pt1=(info['x'], info['y']), pt2=(info['x']+info['w'], info['y']+info['h']), color=(255,0,0), thickness=2)

    cv2.imwrite(chars + '.jpg', img_out)

    plt.figure(figsize=(12, 10))
    plt.imshow(img_out)
except :
    print()
# Out:
# 19노0141

# %%
'''
df = pd.read_excel('plates.xlsx', sheet_name='Sheet1')
row_list = []

df.loc[len(df)] = [chars]
# Excel 파일로 저장
df.to_excel('plates.xlsx', index=False, sheet_name='Sheet1')

df.info
'''
# Out:
# "\ndf = pd.read_excel('plates.xlsx', sheet_name='Sheet1')\nrow_list = []\n\ndf.loc[len(df)] = [chars]\n# Excel 파일로 저장\ndf.to_excel('plates.xlsx', index=False, sheet_name='Sheet1')\n\ndf.info\n"
